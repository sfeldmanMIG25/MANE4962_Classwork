# %% [markdown]
# <a href="https://colab.research.google.com/github/sfeldmanMIG25/MANE4962_Classwork/blob/main/Class_5_Assignment_Feldman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Stephen Feldman RIN: 662047892
# In class - assignment in class (Class 5)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.5, random_state=42)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix

# 1. Train KNN with raw data
knn_raw = KNeighborsClassifier()
knn_raw.fit(X_train, y_train)
y_pred_raw = knn_raw.predict(X_test)
accuracy_raw = accuracy_score(y_test, y_pred_raw)

# 2. Train KNN with scaled data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn_scaled = KNeighborsClassifier()
knn_scaled.fit(X_train_scaled, y_train)
y_pred_scaled = knn_scaled.predict(X_test_scaled)
accuracy_scaled = accuracy_score(y_test, y_pred_scaled)

# Compare accuracy
print(f"Accuracy (Raw Data): {accuracy_raw}")
print(f"Accuracy (Scaled Data): {accuracy_scaled}")

# Confusion Matrix
cm_raw = confusion_matrix(y_test, y_pred_raw)
cm_scaled = confusion_matrix(y_test, y_pred_scaled)

# Plot Confusion Matrices
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.heatmap(cm_raw, annot=True, ax=axes[0], cmap="Blues", fmt="d")
axes[0].set_title("Confusion Matrix (Raw Data)")
sns.heatmap(cm_scaled, annot=True, ax=axes[1], cmap="Blues", fmt="d")
axes[1].set_title("Confusion Matrix (Scaled Data)")
plt.show()


# Visualize Scaling Effects (Example: Feature 1 vs Feature 2)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.title("Raw Data (Feature 1 vs Feature 2)")
plt.subplot(1, 2, 2)
plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=y_train)
plt.title("Scaled Data (Feature 1 vs Feature 2)")
plt.show()
# Out:
# Accuracy (Raw Data): 0.9466666666666667
# Accuracy (Scaled Data): 0.96
